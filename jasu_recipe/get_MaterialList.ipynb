# %%
# -＊- coding: utf-8 -＊-

import requests
from pprint import pprint
from time import sleep
from itertools import islice

url = 'https://app.rakuten.co.jp/services/api/Recipe/CategoryRanking/20170426?'

def get_ingredient(id):
    payload = {
       'applicationId': [1098435242683481258],
       'categoryId': id.strip(),
       }
    r = requests.get(url, params=payload)
    resp = r.json()
    for recipe in resp['result']:
        for food in recipe["recipeMaterial"]:
            normalized_food = food.strip(rm_char).replace('(', ' ').replace('（', ' ').split(" ")[0]
            yield normalized_food

lack_set = set()
lack_list = []
idlist_all = open('idlist_all.txt','r')

for Id in islice(idlist_all, 43):
    for j in get_ingredient(Id):
        lack_set.add(j)
    sleep(1.5)
lack_list = list(lack_set)
print(lack_list)

file = open('ingredient_list.txt', 'w')
for k in lack_list:
    file.writelines(k)
    file.writelines('\n')
# Out:
# ['', 'せり', 'ピザチーズ', 'チリパウダー', '冷水', 'ギリシャヨーグルト', 'ゆで卵', 'スープ', 'オリーブオイル', '鳥ガラスープの素', '胡麻油', 'おろにしょうが', '黒コショウ', '葛きり', '合いびき肉', '豚こま肉', '強力粉', 'ヨーグルト', '豚ロース薄切り肉', 'チョコレート', 'デコレーション', '酢、水', '塩・黒コショウ', 'エノキ', 'お好みのジャム\u3000又は砂糖', '長ネギ', 'ミルクココア', '絹ごし豆腐', '牛肉薄切り', '鶏手羽元', '鶏肉', 'シュレッドチーズ', 'だし汁', '豚こま切れ肉', '甘酢あん', '鷹の爪の輪切りor粉', 'ミニトマト', 'きのこ', '鷹の爪', '練乳の方がコクが出て美味しいのですが…', 'すし酢', '白ワイン', '揚げ油', '海苔', '生姜の甘酢漬け', '酒、みりん', '塩胡椒', 'りんごジャムまたはマーマレード', '氷砂糖', 'コーンスターチ', 'しめじ、エリンギ、えのき\u3000など合わせて', 'むきエビ', '焼きそば麺', 'アボカド', '白ワインビネガー\u3000または\u3000酢', '輪切り赤唐辛子', '食パン6枚切り', '薄力粉or強力粉', '里芋', '顆粒だし', 'ラム酒', '醤油', 'ピザ用チーズ', 'カニ脚肉', 'マーガリン', '豆腐', '鯛でんぷ', 'ウェイパー', '赤唐辛子\u3000お好みで', 'にんにくチュープ', 'ごま油', '卵\u3000Ｍサイズ', 'なす', 'わさび', 'ナス', 'にんにくチューブ、生姜チューブ', 'バターorマーガリン', 'お好みのスパイス', '塩こしょう', '胡椒', 'ハム', '日本酒', 'きゅうり', '加熱したかぼちゃ', '純生クリーム', 'しょうが', '青のり', 'つやだし用溶き卵', 'チョコチップ', 'カニカマ', '水菜', 'じゃがいも', '砂糖', '糸赤唐辛子', '寿司酢', 'ニンニク', 'レシピ', '牛もも肉塊', 'おろしにんにく', 'お餅', 'クレイジーソルト', 'スライスチーズ', 'キャベツ', 'パルメザンチーズ', 'おろししょうが', '味噌', 'Ａ', 'ケチャップ', 'ロースハム', '酒・みりん', 'じゃが芋', '生姜みじん切り', 'ハム・ベーコンなど', 'むね', 'パセリのみじんぎり', '粉チーズ', 'だし巻き卵', '薄あげ', 'エキストラバージンオリーブオイル', 'ごぼう', 'ほうれん草', 'サルサソースの材料', 'マッシュルーム', 'サクサク衣＞の材料', '顆粒だしの素', '酢', '豚バラ肉', 'ハーフベーコン', 'ねぎ', 'すりゴマ', 'そうめん', 'しめじ', 'しょうゆ、砂糖', 'にんにくのすりおろし', 'タルタルソース', 'つくねの材料', '金柑', '鮭切り身', '玉子', 'ソーセージ', '玉葱', '焼き油', 'すし飯', '生姜', 'トマト', '出し汁', '酒', '水溶き片栗粉', '塩、こしょう', '和風だしの素', '鶏もも肉', '万能ねぎ', '牛乳', 'にんにくすりおろし', '豚ひき肉', 'にんにくすりおりし', 'チューブの生姜でも', 'ご飯', 'きりたんぽのスープ', 'ひき肉', '食パン', 'お好みソース', '水＋椎茸の戻し汁', 'カレー粉', '殻付き', 'オイスターソース、酒', '厚揚げ\u30002個入り', '黒ゴマ', 'パスタ', 'タコスミートの材料', 'ホットケーキミックス', '鶏挽き肉', 'ラー油', '山椒', '塩コショウ', '餃子の皮', '大豆水煮', '大葉', 'でんぶ', '細ねぎ', 'きび砂糖', '昆布', 'マヨネーズ', '水', 'ニンニクみじん切り', '顆粒コンソメ', 'フランスパン', 'おろしニンニク', 'みりん', 'パン粉', 'ガナッシュ', '蒲鉾', 'レモン果汁', 'ミルクチョコレート', 'ソース', 'タバスコ', '無農薬レモン', '生クリーム', 'テフロン加工のフライパン', '長ねぎ', '卵焼き', 'トマト缶', '蜂蜜', '塩', '味噌、酒', '塩、胡椒', '茄子', '鮭の切り身', '人参', '具', 'レモン汁', 'タマネギ', '溶かしバター', '卵', '無塩バター', 'ベーコン', 'りんご', '炒め用サラダ油', 'ウスターソース', '塩コショー', '塩・コショウ', '甘塩鮭', 'コチュジャン', 'かぼちゃ', '固形コンソメ', 'お酒', '砂糖６０ｇ、牛乳大さじ１、水小さじ２', '味噌、酒、しょうゆ', 'バジル', 'リンゴ', '美味しい塩', 'しょうゆ', 'Ｂ', '絹とうふ', 'のり巻きの具', 'サラダ油', '＝＝＝＝＝＝スープ＝＝＝＝＝＝', 'めんつゆ', '小麦粉', '鶏スープの素', '卵黄', '冷凍グリーンピース', '酒粕', 'はちみつ', '甘酢', 'スライス餅', 'グレーズ用', '醤油・みりん・砂糖', '和風だし', '赤唐辛子', 'すりおろしニンニク', 'いちご', 'ゴーヤー', 'オリーブ・オイル', '生椎茸', '粗塩', 'さば水煮缶', 'ベーキングパウダー', 'ささみ', 'しいたけ', 'ポン酢', '具は何でも', 'コショウ', '冷凍牡蠣', '海老', '豚肉', '片栗粉', 'ホワイトチョコ', '赤ワインまたは料理酒', '白ネギ', '調味料', 'ナムルダレ', 'かんぴょうの煮物', 'コンソメ', '薄力粉', '生姜のすりおろし', 'あれば】牛乳', 'きのこ類', '鶏ささ身', 'ホワイトラム', 'お米', 'バニラエッセンス', '牛豚合挽肉', 'すりごま', 'グラニュー糖', '赤ワイン', 'とんかつソース', '米麹', 'レタス', 'パセリ', '絹豆腐', '玉ねぎすりおろし', '鶏がらスープの素', '塩昆布', '仕上げに', '梅干し', 'えのき茸', '野菜類＞お好みで', '飾り用パセリ', 'スポンジ生地', '愛情', '照り焼きのタレ', 'いちごジャム', 'ごま油、サラダ油', '塩・こしょう', '白だし', '柚子の皮', 'いりごま', 'もやし', '生姜チュープ', 'ピーマン', 'なす\u3000', 'ブロッコリー', 'ショウガ', '白ゴマ', 'オリーブ油', 'タレの材料', 'かつおぶし', '中華', '白ねぎ', 'とろけるチーズ', '中華麺', 'れんこん', 'マヨダレ', '参考に', '肉', '鶏ガラスープの素', 'みそ', 'コンソメの素', '粉砂糖', '焼海苔', 'エビ', '溶き卵', 'おろし生姜', 'たまご', '豚こまぎれ肉', '高野豆腐の煮物', '青ねぎ', '豆板醤', '舞茸', 'ローズマリー', 'サニーレタス', 'しょう油', '食紅\u3000赤', 'まぐろ', 'ニラ', 'さとう', 'ゴマ油', 'にんじん、ネギ', 'みょうが', 'えのき', 'ダシの素', '塩・胡椒', 'かつお', 'さつまいも', '鶏むね肉', 'トマトケチャップ、オイスターソース', 'サラダオイル', '梅肉', '牛バラ肉', 'なければチューブの生姜を料理酒で溶く', '鶏挽肉', '大根', 'たまねぎ', '板チョコ', '盛り付け用の材料', '刻み海苔', 'キュウリ', '料理酒', '三つ葉', '煮リンゴの材料≫作りやすい分量', '油', '玉ねぎ', 'ブリの切り身', 'あんの材料', 'リーフレタス', 'にら', 'こんにゃく', 'ブラックペッパー', '食パン\u30006枚切り', '春雨', 'にんじん', '春菊', '白菜', 'きゃべつ', 'バターサブレ', '生姜のしぼり汁', '鶏がらスープのもと', 'だしの素', '白身魚切り身', 'かつお節', 'さば', '焼き海苔', 'ニンジン', 'きりたんぽ', '熱湯', 'バター有塩', '鶏胸肉', 'サラダ菜', '茹で汁', '中華だし', '長ネギみじん切り', 'レタスなど', '牡蠣', 'プレーンヨーグルト', '冷凍パイシート', '焼きそば用の麺', '手羽元or鶏もも肉', 'こしょう', 'もつ', 'ココアパウダー', '本だし', '干ししいたけの煮物', 'かんぴょう', '市販のカレールー', '三温糖', '生姜のすり下ろし', '味付け用', 'バジルorイタリアンパセリ', 'レモン', 'バター', 'にんにく', '生ハム', '干し椎茸', 'バゲット', 'オイスターソース', 'ドリトス', 'ウィンナー']

# %%
test_list = ['A\u3000ゴマ油',
 'A\u3000水',
 'A\u3000砂糖',
 'A\u3000酢',
 'A\u3000醤油',
 'Aお酒',
 'Aみそ',
 'Aみりん',
 'Aめんつゆ',
 'Aショウガ',
 'A砂糖',
 'A酒',
 'A醤油',
 'A醤油・みりん・砂糖',
 'A顆粒だし',
 'A顆粒だしの素',
 'or',
 '※ごま油',
 '※コショウ',
 '※パン粉、片栗粉、ウスターソース',
 '※卵',
 '※塩',
 '※練乳の方がコクが出て美味しいのですが…',
 '≪ガナッシュ≫',
 '≪スポンジ生地≫',
 '≪デコレーション≫',
 '≪具は何でも≫',
 '≪煮リンゴの材料≫作りやすい分量',
 '■',
 '■味付け用',
 '□ゴマ油',
 '▲醤油',
 '▼タルタルソース▼',
 '▼甘酢▼',
 '◇こしょう',
 '◇ウスターソース',
 '◇ケチャップ',
 '◇チリパウダー',
 '○お酒',
 '○しょうゆ',
 '○にんじん',
 '○にんにくすりおろし',
 '○みりん',
 '○ウインナーソーセージ',
 '○オリーブオイル',
 '○キャベツ',
 '○タバスコ',
 '○ハーフベーコン',
 '○マッシュルーム',
 '○レモン汁',
 '○人参',
 '○塩',
 '○大根',
 '○小麦粉',
 '○料理酒',
 '○水',
 '○玉ねぎ',
 '○玉ねぎすりおろし',
 '○生姜のしぼり汁']

# %%
import string

# %%
rm_char = string.ascii_lowercase
rm_char += string.ascii_uppercase
rm_char += string.digits
rm_char += string.punctuation
rm_char += string.whitespace
rm_char += '\u3000'
rm_char += '※≪≫■□▲▼◇○●☆★ ◎♪⚫︎【】・＊＜＞～）'

# %%
rm_char
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c\u3000'

# %%
for i in test_list:
    print(i.strip(rm_char))
# Out:
# ゴマ油
# 水
# 砂糖
# 酢
# 醤油
# お酒
# みそ
# みりん
# めんつゆ
# ショウガ
# 砂糖
# 酒
# 醤油
# 醤油・みりん・砂糖
# 顆粒だし
# 顆粒だしの素
#
# ごま油
# コショウ
# パン粉、片栗粉、ウスターソース
# 卵
# 塩
# 練乳の方がコクが出て美味しいのですが…
# ガナッシュ
# スポンジ生地
# デコレーション
# 具は何でも
# 煮リンゴの材料≫作りやすい分量
#
# 味付け用
# ゴマ油
# 醤油
# タルタルソース
# 甘酢
# こしょう
# ウスターソース
# ケチャップ
# チリパウダー
# お酒
# しょうゆ
# にんじん
# にんにくすりおろし
# みりん
# ウインナーソーセージ
# オリーブオイル
# キャベツ
# タバスコ
# ハーフベーコン
# マッシュルーム
# レモン汁
# 人参
# 塩
# 大根
# 小麦粉
# 料理酒
# 水
# 玉ねぎ
# 玉ねぎすりおろし
# 生姜のしぼり汁
